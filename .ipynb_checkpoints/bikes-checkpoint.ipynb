# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')


# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# Out:
# /Users/sules/Desktop/conjestion/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Libraries imported successfully!

# %%
import pandas as pd

# File paths
file_2024 = 'data/JC-202405-citibike-tripdata.csv'
file_2025 = 'data/JC-202505-citibike-tripdata.csv'

# Load the data
df_2024 = pd.read_csv(file_2024)
df_2025 = pd.read_csv(file_2025)

# %%
print(df_2024.columns)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df_2024['started_at'] = pd.to_datetime(df_2024['started_at'])
df_2025['started_at'] = pd.to_datetime(df_2025['started_at'])

df_2024['date'] = df_2024['started_at'].dt.date
df_2025['date'] = df_2025['started_at'].dt.date

# %%
# Updated bounding box for Manhattan below ~60th St
LAT_THRESHOLD = 40.7690   # ~60th St upper boundary
LAT_MIN = 40.68           # Southern tip of Manhattan
LONG_MIN = -74.05         # Includes west side (Hudson River edge)
LONG_MAX = -73.95         # East River edge

def in_congestion_zone(lat, lng):
    return (lat < LAT_THRESHOLD) & (lat > LAT_MIN) & (lng > LONG_MIN) & (lng < LONG_MAX)

# Apply only to trips that START in the zone (for spatial station analysis)
df_2024_zone = df_2024[
    in_congestion_zone(df_2024['start_lat'], df_2024['start_lng'])
]

df_2025_zone = df_2025[
    in_congestion_zone(df_2025['start_lat'], df_2025['start_lng'])
]

# %%
# Prepare the daily aggregates again
daily_2024 = df_2024_zone.groupby(df_2024_zone['date']).size().reset_index(name='trip_count')
daily_2024['cp_period'] = 'before'

daily_2025 = df_2025_zone.groupby(df_2025_zone['date']).size().reset_index(name='trip_count')
daily_2025['cp_period'] = 'after'

# Combine both into one long dataframe
daily_long = pd.concat([daily_2024, daily_2025], ignore_index=True)
#daily_long.rename(columns={'started_at': 'date'}, inplace=True)

# Check
daily_long.head()
# Out:
#          date  trip_count cp_period
# 0  2024-05-01        2729    before
# 1  2024-05-02        2881    before
# 2  2024-05-03        2760    before
# 3  2024-05-04        2473    before
# 4  2024-05-05        1001    before

# %%
import pandas as pd
import matplotlib.pyplot as plt

# assume daily_2024 & daily_2025 already exist

# 1) extract day-of-month
daily_2024['day'] = pd.to_datetime(daily_2024['date']).dt.day
daily_2025['day'] = pd.to_datetime(daily_2025['date']).dt.day

# 2) plot
plt.figure(figsize=(12,6))
plt.plot(
    daily_2024['day'], daily_2024['trip_count'],
    marker='o', label='May 2024'
)
plt.plot(
    daily_2025['day'], daily_2025['trip_count'],
    marker='o', label='May 2025'
)

plt.xticks(range(1,32))
plt.xlabel('Day of May')
plt.ylabel('Trip Count')
plt.title('Citi Bike Trips by Day of May')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
from scipy.stats import ttest_ind

# Split by period
before = daily_long[daily_long['cp_period'] == 'before']['trip_count']
after = daily_long[daily_long['cp_period'] == 'after']['trip_count']

# Drop any NaNs just in case
before = before.dropna()
after = after.dropna()

# Welch's t-test
stat, pvalue = ttest_ind(after, before, equal_var=False)
print(f"Welch’s t = {stat:.2f}, p = {pvalue:.4f}")

if pvalue < 0.05:
    print("✅ Statistically significant difference in daily Citi Bike usage.")
else:
    print("❌ No statistically significant difference.")
# Out:
# Welch’s t = 0.33, p = 0.7431
# ❌ No statistically significant difference.

# %%
# Count trips starting at each station in each month
start_counts_2024 = df_2024_zone.groupby('start_station_id').size().reset_index(name='count_2024')
start_counts_2025 = df_2025_zone.groupby('start_station_id').size().reset_index(name='count_2025')

# Merge the two
station_counts = pd.merge(start_counts_2024, start_counts_2025, on='start_station_id', how='outer').fillna(0)

# Calculate percent change
station_counts['abs_change'] = station_counts['count_2025'] - station_counts['count_2024']
station_counts['pct_change'] = (
    (station_counts['count_2025'] - station_counts['count_2024']) / 
    station_counts['count_2024'].replace(0, 1) * 100
)

# %%
# Get unique coordinates per start station from 2024 data
station_coords = df_2024_zone.groupby('start_station_id').agg({
    'start_station_name': 'first',
    'start_lat': 'first',
    'start_lng': 'first'
}).reset_index()

# Merge with station trip counts
station_counts_geo = pd.merge(station_counts, station_coords, on='start_station_id', how='left')

# Drop rows with missing lat/lng
station_counts_geo = station_counts_geo.dropna(subset=['start_lat', 'start_lng'])

station_counts_geo.head()
# Out:
#   start_station_id  count_2024  count_2025  abs_change  pct_change  \
# 0          5359.11         1.0         0.0        -1.0      -100.0
# 1          5772.05         1.0         0.0        -1.0      -100.0
# 2          6289.06         1.0         0.0        -1.0      -100.0
# 3          6331.01         1.0         0.0        -1.0      -100.0
# 4          6432.11         1.0         0.0        -1.0      -100.0
#
#           start_station_name  start_lat  start_lng
# 0     Leonard St & Church St  40.716586 -74.034231
# 1  Morton St & Washington St  40.705774 -74.028582
# 2         Broadway & W 29 St  40.751587 -74.017700
# 3            W 31 St & 7 Ave  40.712922 -74.032552
# 4         E 40 St & Park Ave  40.722848 -74.046163

# %%
# Define bounding box for lower Manhattan (below 60th Street)
LAT_MAX = 40.7690  # ~60th St
LAT_MIN = 40.68    # bottom of Manhattan
LON_MIN = -74.02   # west side
LON_MAX = -73.95   # east side

# Filter station points
station_counts_geo = station_counts_geo[
    (station_counts_geo['start_lat'] >= LAT_MIN) &
    (station_counts_geo['start_lat'] <= LAT_MAX) &
    (station_counts_geo['start_lng'] >= LON_MIN) &
    (station_counts_geo['start_lng'] <= LON_MAX)
].copy()

# %%
import folium

# Center the map roughly on Midtown Manhattan
map_center = [40.75, -73.98]
m = folium.Map(location=map_center, zoom_start=13)

# Add markers
for _, row in station_counts_geo.iterrows():
    lat = row['start_lat']
    lon = row['start_lng']
    pct = row['pct_change']
    count_2024 = row['count_2024']
    count_2025 = row['count_2025']
    
    # Color and size
    color = 'red' if pct > 0 else 'blue'
    radius = min(max(abs(pct) / 2, 3), 15)  # scale marker size

    popup = folium.Popup(
        f"Station: {row['start_station_name']}<br>"
        f"2024 Trips: {int(count_2024)}<br>"
        f"2025 Trips: {int(count_2025)}<br>"
        f"Change: {pct:.1f}%", max_width=300
    )
    
    folium.CircleMarker(
        location=[lat, lon],
        radius=radius,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=popup
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_833c483e931c209624178d15b97a5661 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_833c483e931c209624178d15b97a5661&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_833c483e931c209624178d15b97a5661 = L.map(
#                 &quot;map_833c483e931c209624178d15b97a5661&quot;,
#                 {
#                     center: [40.75, -73.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_952ae0ee68fa4c479d7a5f6e38cfadd5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_952ae0ee68fa4c479d7a5f6e38cfadd5.addTo(map_833c483e931c209624178d15b97a5661);
#
#
#             var circle_marker_55a94e8781d793dc239c14b282b1e664 = L.circleMarker(
#                 [40.71658575, -74.03423141666667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_833c483e931c209624178d15b97a5661);
#
#
#         var popup_db1c3a691a119f6053ffbc0c0ff6da0b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_c5b0c2104bc140ea8a4d99d22993d434 = $(`&lt;div id=&quot;html_c5b0c2104bc140ea8a4d99d22993d434&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Leonard St &amp; Church St&lt;br&gt;2024 Trips: 1&lt;br&gt;2025 Trips: 0&lt;br&gt;Change: -100.0%&lt;/div&gt;`)[0];
#                 popup_db1c3a691a119f6053ffbc0c0ff6da0b.setContent(html_c5b0c2104bc140ea8a4d99d22993d434);
#
#
#
#         circle_marker_55a94e8781d793dc239c14b282b1e664.bindPopup(popup_db1c3a691a119f6053ffbc0c0ff6da0b)
#         ;
#
#
#
#
#             var circle_marker_bebee85f4461324e65d4ea25abf01b06 = L.circleMarker(
#                 [40.70577398333333, -74.0285825],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_833c483e931c209624178d15b97a5661);
#
#
#         var popup_6343a677465997cefbe04cfe66546494 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_fa15a44216c90e489d5e6d4ff5b2c94b = $(`&lt;div id=&quot;html_fa15a44216c90e489d5e6d4ff5b2c94b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Morton St &amp; Washington St&lt;br&gt;2024 Trips: 1&lt;br&gt;2025 Trips: 0&lt;br&gt;Change: -100.0%&lt;/div&gt;`)[0];
#                 popup_6343a677465997cefbe04cfe66546494.setContent(html_fa15a44216c90e489d5e6d4ff5b2c94b);
#
#
#
#         circle_marker_bebee85f4461324e65d4ea25abf01b06.bindPopup(popup_6343a677465997cefbe04cfe66546494)
#         ;
#
#
#
#
#             var circle_marker_b7cc93fe8d9ee35d8ce6eb66b983f6e2 = L.circleMarker(
#                 [40.7515868, -74.01769965],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_833c483e931c209624178d15b97a5661);
#
#
#         var popup_dd8577ff5324519fbed027f416efcda0 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e0594a7ba93c85264ed78603c7b76e7e = $(`&lt;div id=&quot;html_e0594a7ba93c85264ed78603c7b76e7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station: Broadway &amp; W 29 St&lt;br&gt;2024 Trips: 1&lt;br&gt;2025 Trips: 0&lt;br&gt;Change: -100.0%&lt;/div&gt;`)[0];
#                 popup_dd8577ff5324519fbed027f416efcda0.setContent(html_e0594a7ba9

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
plt.scatter(station_counts_geo['start_lng'], station_counts_geo['start_lat'], alpha=0.7)
plt.title("Start Station Locations (Filtered)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True)
plt.show()
